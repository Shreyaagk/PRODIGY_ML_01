# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\shrey\Downloads\archive (3)\House Price India.csv")
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
features =["Area of the basement","number of bedrooms","number of bathrooms"]

# %%
x =df[features]
y =df["Price"]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
y_pred =model.predict(x_test)

# %%
mse =mean_squared_error(y_test,y_pred)

# %%
r2 =r2_score(y_test,y_pred)

# %%
print(f'Mean Squared Error: {mse}')
print(f'R_squared: {r2}')
# Out:
# Mean Squared Error: 93795500170.39168
# R_squared: 0.3344010869348998

# %%
plt.scatter(y_test,y_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Prices vs Predicted Prices")
plt.show()

# %%
import pandas as pd

# Inputs from the user (using float instead of int)
Area = int(input("Enter the area: "))
Bedroom = int(input("Enter the number of bedrooms: "))
Bathroom = float(input("Enter the number of bathrooms: "))

# Correctly create the DataFrame with column names and values
new_data = pd.DataFrame({
    "Area": [Area], 
    "Bedroom": [Bedroom], 
    "Bathroom": [Bathroom]
})

# Use the trained model for prediction
predicted_price = model.predict(new_data)

# Output the predicted price
print(f'Predicted Price: {predicted_price[0]}')
# Out:
# Enter the area:  280
# Enter the number of bedrooms:  5
# Enter the number of bathrooms:  2.50
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 16
#       9 new_data = pd.DataFrame({
#      10     "Area": [Area],
#      11     "Bedroom": [Bedroom],
#      12     "Bathroom": [Bathroom]
#      13 })
#      15 # Use the trained model for prediction
# ---> 16 predicted_price = model.predict(new_data)
#      18 # Output the predicted price
#      19 print(f'Predicted Price: {predicted_price[0]}')
#
# NameError: name 'model' is not defined
